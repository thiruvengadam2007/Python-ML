# %%
import pandas as pd
pd.set_option('display.max_columns', 10)
print("Original data:\n")
df = pd.read_excel("/content/dcp_excel.xlsx")
print(df)
# Out:
# Original data:
#
#    Unnamed: 0  ROLL      NAME  ENGLISH  TAMIL  MATHS  SCIENCE  SOCIAL  TOTAL
# 0           0   101      YASH     65.0     84     50       54      50    303
# 1           1   102     YUGAN     81.0     56     54       67      64    322
# 2           2   103       DEV     67.0     75     72       83      83    380
# 3           3   104     VENKY     56.0     71     80       71      53    331
# 4           4   105     SANDY      NaN     94     94       85      91    364
# 5           5   106  SRIKNATH     98.0     68     61       69      72    368
# 6           6   107     ROHAN     87.0     58     76       71      61    353

# %%
f=df['NAME'].str.strip()
f.to_excel("/content/dcap.xlsx")
print("\nReplace value:")
k=df.ffill()
print(k)
print("\nUpdated list\n")
k.to_excel("/content/dcap.xlsx")
# Out:
# Replace value:
#    Unnamed: 0  ROLL      NAME  ENGLISH  TAMIL  MATHS  SCIENCE  SOCIAL  TOTAL
# 0           0   101      YASH     65.0     84     50       54      50    303
# 1           1   102     YUGAN     81.0     56     54       67      64    322
# 2           2   103       DEV     67.0     75     72       83      83    380
# 3           3   104     VENKY     56.0     71     80       71      53    331
# 4           4   105     SANDY     56.0     94     94       85      91    364
# 5           5   106  SRIKNATH     98.0     68     61       69      72    368
# 6           6   107     ROHAN     87.0     58     76       71      61    353
#
# Updated list

# %%
print("\nDrop one particular column and its values:\n")
k.drop(['SOCIAL'],axis=1,inplace=True)
print(k)
print("\nUpdated list..\n")
k.to_excel("/content/dcap.xlsx")
# Out:
# Drop one particular column and its values:
#
#    Unnamed: 0  ROLL      NAME  ENGLISH  TAMIL  MATHS  SCIENCE  TOTAL
# 0           0   101      YASH     65.0     84     50       54    303
# 1           1   102     YUGAN     81.0     56     54       67    322
# 2           2   103       DEV     67.0     75     72       83    380
# 3           3   104     VENKY     56.0     71     80       71    331
# 4           4   105     SANDY     56.0     94     94       85    364
# 5           5   106  SRIKNATH     98.0     68     61       69    368
# 6           6   107     ROHAN     87.0     58     76       71    353
#
# Updated list..

# %%
print("\nDrop NaN rows:\n")
df=pd.read_excel("/content/dcap_excel.xlsx")
print(df)
x=df.dropna()
print(x)
print("\nUpdated data list:\n")
x.to_excel("/content/dcap_excel.xlsx")
# Out:
# Drop NaN rows:
#
#    Unnamed: 0  ROLL      NAME  ENGLISH  TAMIL  MATHS  SCIENCE  SOCIAL  TOTAL
# 0           0   101      YASH     65.0     84     50       54      50    303
# 1           1   102     YUGAN     81.0     56     54       67      64    322
# 2           2   103       DEV     67.0     75     72       83      83    380
# 3           3   104     VENKY     56.0     71     80       71      53    331
# 4           4   105     SANDY      NaN     94     94       85      91    364
# 5           5   106  SRIKANTH     98.0     68     61       69      72    368
# 6           6   107     ROHAN     87.0     58     76       71      61    353
#    Unnamed: 0  ROLL      NAME  ENGLISH  TAMIL  MATHS  SCIENCE  SOCIAL  TOTAL
# 0           0   101      YASH     65.0     84     50       54      50    303
# 1           1   102     YUGAN     81.0     56     54       67      64    322
# 2           2   103       DEV     67.0     75     72       83      83    380
# ...

# %%
print("\nReplace values:\n")
n=pd.read_excel("/content/dcap_excel.xlsx")
print("\nOriginal data:\n")
print(n)
y=n.replace({89:88})
print("\nReplaced dataset:\n")
print(y)
print("\nUpdated dataset:\n")
y.to_excel("/content/dcap_excel.xlsx")
# Out:
# Replace values:
#
#
# Original data:
#
#    Unnamed: 0.1  Unnamed: 0  ROLL      NAME  ENGLISH  TAMIL  MATHS  SCIENCE  \
# 0             0           0   101      YASH       65     84     50       54
# 1             1           1   102     YUGAN       81     56     54       67
# 2             2           2   103       DEV       67     75     72       83
# 3             3           3   104     VENKY       56     71     80       71
# 4             5           5   106  SRIKANTH       98     68     61       69
# 5             6           6   107     ROHAN       87     58     76       71
#
#    SOCIAL  TOTAL
# 0      50    303
# 1      64    322
# 2      83    380
# 3      53    331
# 4      72    368
# 5      61    353
#
# Replaced dataset:
#
#    Unnamed: 0.1  Unnamed: 0  ROLL      NAME  ENGLISH  TAMIL  MATHS  SCIENCE  \
# 0             0           0   101      YASH       65     84     50       54
# 1             1           1   102     YUGAN       81     56     54       67
# ...

# %%
df=pd.read_excel("/content/dcap_excel.xlsx")
print(df)
print("\nExtract using isin() function:\n")
new=df['ENGLISH'].isin([88])
print(df[new])
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  ROLL      NAME  ENGLISH  TAMIL  \
# 0             0             0           0   101      YASH       65     84
# 1             1             1           1   102     YUGAN       81     56
# 2             2             2           2   103       DEV       67     75
# 3             3             3           3   104     VENKY       56     71
# 4             4             5           5   106  SRIKANTH       98     68
# 5             5             6           6   107     ROHAN       87     58
#
#    MATHS  SCIENCE  SOCIAL  TOTAL
# 0     50       54      50    303
# 1     54       67      64    322
# 2     72       83      83    380
# 3     80       71      53    331
# 4     61       69      72    368
# 5     76       71      61    353
#
# Extract using isin() function:
#
# Empty DataFrame
# Columns: [Unnamed: 0.2, Unnamed: 0.1, Unnamed: 0, ROLL, NAME, ENGLISH, TAMIL, MATHS, SCIENCE, SOCIAL, TOTAL]
# Index: []
